# %%
#计算三个方面的tfidf

#v方面
path0_v = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type0_v.txt"
path1_v = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type1_v.txt"
path2_v = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type2_v.txt"
path3_v = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type3_v.txt"
path4_v = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type4_v.txt"
path5_v = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type5_v.txt"

path0_i = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type0_i.txt"
path1_i = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type1_i.txt"
path2_i = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type2_i.txt"
path3_i = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type3_i.txt"
path4_i = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type4_i.txt"
path5_i = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type5_i.txt"

path0_t = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type0_t.txt"
path1_t = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type1_t.txt"
path2_t = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type2_t.txt"
path3_t = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type3_t.txt"
path4_t = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type4_t.txt"
path5_t = "/home/user/Programs/PMA_lihang/mypaper/label_description/for_others/att_type5_t.txt"




f0_v = open(path0_v, 'r')
f1_v = open(path1_v, 'r')
f2_v = open(path2_v, 'r')
f3_v = open(path3_v, 'r')
f4_v = open(path4_v, 'r')
f5_v = open(path5_v, 'r')

f0_i = open(path0_i, 'r')
f1_i = open(path1_i, 'r')
f2_i = open(path2_i, 'r')
f3_i = open(path3_i, 'r')
f4_i = open(path4_i, 'r')
f5_i = open(path5_i, 'r')

f0_t = open(path0_t, 'r')
f1_t = open(path1_t, 'r')
f2_t = open(path2_t, 'r')
f3_t = open(path3_t, 'r')
f4_t = open(path4_t, 'r')
f5_t = open(path5_t, 'r')


lines0v = f0_v.readlines()
lines1v = f1_v.readlines()
lines2v = f2_v.readlines()
lines3v = f3_v.readlines()
lines4v = f4_v.readlines()
lines5v = f5_v.readlines()

lines0i = f0_i.readlines()
lines1i = f1_i.readlines()
lines2i = f2_i.readlines()
lines3i = f3_i.readlines()
lines4i = f4_i.readlines()
lines5i = f5_i.readlines()

lines0t = f0_t.readlines()
lines1t = f1_t.readlines()
lines2t = f2_t.readlines()
lines3t = f3_t.readlines()
lines4t = f4_t.readlines()
lines5t = f5_t.readlines()



v0 = ""
v1 = ""
v2 = ""
v3 = ""
v4 = ""
v5 = ""
for line in lines0v:
    v0 += line + " "
for line in lines1v:
    v1 += line + " "
for line in lines2v:
    v2 += line + " "
for line in lines3v:
    v3 += line + " "
for line in lines4v:
    v4 += line + " "
for line in lines5v:
    v5 += line + " "

i0 = ""
i1 = ""
i2 = ""
i3 = ""
i4 = ""
i5 = ""
for line in lines0i:
    i0 += line + " "
for line in lines1i:
    i1 += line + " "
for line in lines2i:
    i2 += line + " "
for line in lines3i:
    i3 += line + " "
for line in lines4i:
    i4 += line + " "
for line in lines5i:
    i5 += line + " "

t0 = ""
t1 = ""
t2 = ""
t3 = ""
t4 = ""
t5 = ""
for line in lines0t:
    t0 += line + " "
for line in lines1t:
    t1 += line + " "
for line in lines2t:
    t2 += line + " "
for line in lines3t:
    t3 += line + " "
for line in lines4t:
    t4 += line + " "
for line in lines5t:
    t5 += line + " "




from gensim.parsing.preprocessing import STOPWORDS 
import numpy 
stop_words = STOPWORDS 
# 字符串过滤停用词+小写
def filter(tokens):
    filtered_tokens = [token for token in tokens if token not in stop_words and len(token) > 1] 
    #拼成字符串
    filtered_tokens = ' '.join(filtered_tokens)
    #小写
    filtered_tokens = filtered_tokens.lower()
    return filtered_tokens

v0 = filter(v0.split())
v1 = filter(v1.split())
v2 = filter(v2.split())
v3 = filter(v3.split())
v4 = filter(v4.split())
v5 = filter(v5.split())

i0 = filter(i0.split())
i1 = filter(i1.split())
i2 = filter(i2.split())
i3 = filter(i3.split())
i4 = filter(i4.split())
i5 = filter(i5.split())

t0 = filter(t0.split())
t1 = filter(t1.split())
t2 = filter(t2.split())
t3 = filter(t3.split())
t4 = filter(t4.split())
t5 = filter(t5.split())



documents_v = [v0,v1,v2,v3,v4,v5]
documents_i = [i0,i1,i2,i3,i4,i5]
documents_t = [t0,t1,t2,t3,t4,t5]

# 导入TfidfVectorizer类
from sklearn.feature_extraction.text import TfidfVectorizer

#统计词频，返回单词和词频的字典
# def tfidf(documentsd,index):
#     str = documentsd[index]
#     dict = {}
#     for i in str.split():
#         if i in dict:
#             dict[i] += 1
#         else:
#             dict[i] = 1

#     #排序，根据词频从大到小排序
#     dict = sorted(dict.items(), key=lambda x: x[1], reverse=True)
    
#     return dict


def tfidf(documents,index):
    # 初始化一个TfidfVectorizer对象
    vectorizer = TfidfVectorizer()
    # 调用fit_transform方法计算TF-IDF值
    tfidf_matrix = vectorizer.fit_transform(documents)
    #输出第一句话的单词和对应的TF-IDF值
    # print(vectorizer.get_feature_names())
    # print(tfidf_matrix.toarray()[0])
    #构建字典来存储每个单词的TF-IDF值
    # word2tfidf = dict(zip(vectorizer.get_feature_names(), tfidf_matrix.toarray()[index]))

    ##构建字典来存储每个单词的TF-IDF值,使用get_feature_names_out()方法
    word2tfidf = dict(zip(vectorizer.get_feature_names_out(), tfidf_matrix.toarray()[index]))
    # print(word2tfidf)
    #排序, 按照TF-IDF值从大到小排序
    sorted_word2tfidf = sorted(word2tfidf.items(), key=lambda x: x[1], reverse=True)
    # print(sorted_word2tfidf)
    return sorted_word2tfidf

sorted_word2tfidf0_v = tfidf(documents_v,0)
#输出前10个
print(sorted_word2tfidf0_v[:110])
sorted_word2tfidf1_v = tfidf(documents_v,1)
print(sorted_word2tfidf1_v[:110])
sorted_word2tfidf2_v = tfidf(documents_v,2)
#输出前10个
print(sorted_word2tfidf2_v[:110])
sorted_word2tfidf3_v = tfidf(documents_v,3)
print(sorted_word2tfidf3_v[:110])
sorted_word2tfidf4_v = tfidf(documents_v,4)
#输出前10个
print(sorted_word2tfidf4_v[:110])
sorted_word2tfidf5_v = tfidf(documents_v,5)
#输出前10个
print(sorted_word2tfidf5_v[:110])

sorted_word2tfidf0_i = tfidf(documents_i,0)
#输出前10个
print(sorted_word2tfidf0_i[:110])
sorted_word2tfidf1_i = tfidf(documents_i,1)
print(sorted_word2tfidf1_i[:110])
sorted_word2tfidf2_i = tfidf(documents_i,2)
#输出前10个
print(sorted_word2tfidf2_i[:110])
sorted_word2tfidf3_i = tfidf(documents_i,3)
print(sorted_word2tfidf3_i[:110])
sorted_word2tfidf4_i = tfidf(documents_i,4)
#输出前10个
print(sorted_word2tfidf4_i[:110])
sorted_word2tfidf5_i = tfidf(documents_i,5)
#输出前10个
print(sorted_word2tfidf5_i[:110])

sorted_word2tfidf0_t = tfidf(documents_t,0)
#输出前10个
print(sorted_word2tfidf0_t[:110])
sorted_word2tfidf1_t = tfidf(documents_t,1)
print(sorted_word2tfidf1_t[:110])
sorted_word2tfidf2_t = tfidf(documents_t,2)
#输出前10个
print(sorted_word2tfidf2_t[:110])
sorted_word2tfidf3_t = tfidf(documents_t,3)
print(sorted_word2tfidf3_t[:110])
sorted_word2tfidf4_t = tfidf(documents_t,4)
#输出前10个
print(sorted_word2tfidf4_t[:110])
sorted_word2tfidf5_t = tfidf(documents_t,5)
#输出前10个
print(sorted_word2tfidf5_t[:110])
# Out:
# [('parameter', 0.47504946127209086), ('php', 0.37214189902850703), ('crafted', 0.3328893007868478), ('vectors', 0.24320055360706855), ('vulnerability', 0.21952188319102364), ('cve', 0.18854614471603776), ('successful', 0.1610997635947736), ('file', 0.1382237128282976), ('unspecified', 0.13771901647839965), ('aka', 0.11969715098412746), ('related', 0.11492356467467614), ('compromise', 0.11001428950277954), ('url', 0.10987323921620369), ('attacks', 0.1072269453387326), ('request', 0.10638578475556937), ('note', 0.10451420245803118), ('unknown', 0.10028737052763596), ('dot', 0.0960875091797991), ('unauthorized', 0.0921600846297463), ('information', 0.08403194225800656), ('oracle', 0.08123862264337424), ('different', 0.07921629791939708), ('id', 0.07585165558674416), ('result', 0.07201102291903609), ('page', 0.0710644675116069), ('access', 0.07103601124813468), ('web', 0.06939574811096638), ('action', 0.06934125125705633), ('site', 0.06795715045093785), ('long', 0.0632763048684539), ('parameters', 0.06242052570369436), ('attacker', 0.05801905122368371), ('index', 0.057327278778147375), ('certificate', 0.05623749299103666), ('obtained', 0.05531003808413801), ('http', 0.05487594297942049), ('admin', 0.05368668105726587), ('server', 0.05300710281603466), ('html', 0.052362246301911), ('human', 0.05140012305885695), ('person', 0.05087901582047223), ('bug', 0.05065889612100546), ('party', 0.050604308320252867), ('details', 0.050361601805527435), ('data', 0.045611932622026084), ('message', 0.04477077203886286), ('issue', 0.04456048189307205), ('demonstrated', 0.0443922497764394), ('user', 0.04361417623701342), ('2015', 0.04337165418143495), ('packet', 0.041599896623939286), ('2016', 0.03794634089559305), ('field', 0.037705023140291734), ('affected', 0.035959614930228034), ('direct', 0.03526525658960547), ('memory', 0.03503433828874848), ('sending', 0.0349982794234075), ('cvss', 0.03437144793308688), ('2014', 0.034172148691006175), ('code', 0.034172148691006175), ('asp', 0.033894261143023595), ('exploit', 0.03368766424389016), ('device', 0.03341510416615927), ('significantly', 0.03250200849397815), ('products', 0.03215177010582006), ('require', 0.03133673397551518), ('header', 0.030775186067184955), ('function', 0.030555158183404287), ('error', 0.030365897052192562), ('allow', 0.02996634577519003), ('malformed', 0.029840171687715543), ('string', 0.029587823512766575), ('triggers', 0.02920930125034312), ('document', 0.029027699161161834), ('interaction', 0.02885780460085403), ('certain', 0.028305053623442652), ('solely', 0.02820557750234228), ('inc', 0.02784480848777744), ('provenance', 0.027683123736217445), ('corruption', 0.02702228373411873), ('packets', 0.026980225704960566), ('value', 0.02681199358832792), ('
350257861653), ('dll', 0.009134294980452188), ('simple', 0.009134294980452188), ('archive_read_support_format_tar', 0.008914521229739096), ('flipbook', 0.008914521229739096), ('html5', 0.008914521229739096), ('netrw', 0.008914521229739096), ('testimonials', 0.008914521229739096), ('argument', 0.008814368764736727), ('blacklist', 0.008814368764736727), ('google', 0.008814368764736727), ('request', 0.008814368764736727), ('video', 0.008814368764736727), ('checks', 0.008228845050113509), ('developer', 0.008228845050113509), ('download', 0.008228845050113509), ('drop', 0.008228845050113509), ('woocommerce', 0.008228845050113509), ('zone', 0.008228845050113509), ('10', 0.007914300221024274), ('java', 0.007914300221024274), ('manager', 0.007914300221024274), ('web', 0.007914300221024274), ('incomplete', 0.0076119124837101555), ('microsoft', 0.0076119124837101555), ('category', 0.0073100349323800586), ('firefox', 0.0073100349323800586), ('grid', 0.0073100349323800586), ('portfolio', 0.0073100349323800586), ('seamonkey', 0.0073100349323800586), ('toolbar', 0.0073100349323800586), ('visual', 0.0073100349323800586), ('widget', 0.0073100349323800586), ('widgets', 0.0073100349323800586), ('13', 0.007051495011789382), ('19', 0.007051495011789382), ('handle', 0.007051495011789382), ('signedness', 0.007051495011789382), ('start', 0.007051495011789382), ('viewer', 0.007051495011789382), ('companion', 0.006171633787585132), ('custom', 0.006171633787585132), ('event', 0.006171633787585132), ('list', 0.006171633787585132), ('12', 0.006089529986968125), ('mail', 0.006089529986968125), ('1410', 0.005943014153159397), ('balloon', 0.005943014153159397), ('gtkutils', 0.005943014153159397), ('icat', 0.005943014153159397)]

# %%
#计算各自字典中值不为0的个数
def count_not_zero(sorted_word2tfidf):
    count = 0
    for i in range(len(sorted_word2tfidf)):
        if sorted_word2tfidf[i][1] != 0:
            count += 1
    return count

# print(count_not_zero(sorted_word2tfidf0_v))
# print(count_not_zero(sorted_word2tfidf1_v))
# print(count_not_zero(sorted_word2tfidf2_v))
# print(count_not_zero(sorted_word2tfidf3_v))
# print(count_not_zero(sorted_word2tfidf4_v))
# print(count_not_zero(sorted_word2tfidf5_v))
import matplotlib.pyplot as plt
import numpy as np
#维护集合，将所有的词汇放入集合中
def maintain_set(sorted_word2tfidf):
    set_words = set()
    # bb= 0
    # list_temp = []
    # last_ = count_not_zero(sorted_word2tfidf)
    for i in range(int(count_not_zero(sorted_word2tfidf) )):
        
        # list_temp.append(sorted_word2tfidf[i][1])
            
        set_words.add(sorted_word2tfidf[i][0])
        # bb += 1
        # if bb >1000:
        #     break
    # plt.plot(list_temp)
    # plt.show()
    return set_words
print("111vvv"*10)
set_v0 = maintain_set(sorted_word2tfidf0_v)
print("222vvv"*10)
set_v1 = maintain_set(sorted_word2tfidf1_v)
# set_v2 = maintain_set(sorted_word2tfidf2_v)
# set_v3 = maintain_set(sorted_word2tfidf3_v)
# set_v4 = maintain_set(sorted_word2tfidf4_v)
# set_v5 = maintain_set(sorted_word2tfidf5_v)
print("111iii"*10)
set_i0 = maintain_set(sorted_word2tfidf0_i)
print("222iii"*10)
set_i1 = maintain_set(sorted_word2tfidf1_i)
# set_i2 = maintain_set(sorted_word2tfidf2_i)
# set_i3 = maintain_set(sorted_word2tfidf3_i)
# set_i4 = maintain_set(sorted_word2tfidf4_i)
# set_i5 = maintain_set(sorted_word2tfidf5_i)
print("111ttt"*10)
set_t0 = maintain_set(sorted_word2tfidf0_t)
print("222ttt"*10)
set_t1 = maintain_set(sorted_word2tfidf1_t)
# set_t2 = maintain_set(sorted_word2tfidf2_t)
# set_t3 = maintain_set(sorted_word2tfidf3_t)
# set_t4 = maintain_set(sorted_word2tfidf4_t)
# set_t5 = maintain_set(sorted_word2tfidf5_t)
# Out:
# 111vvv111vvv111vvv111vvv111vvv111vvv111vvv111vvv111vvv111vvv
# 222vvv222vvv222vvv222vvv222vvv222vvv222vvv222vvv222vvv222vvv
# 111iii111iii111iii111iii111iii111iii111iii111iii111iii111iii
# 222iii222iii222iii222iii222iii222iii222iii222iii222iii222iii
# 111ttt111ttt111ttt111ttt111ttt111ttt111ttt111ttt111ttt111ttt
# 222ttt222ttt222ttt222ttt222ttt222ttt222ttt222ttt222ttt222ttt

# %%
#专门处理other类

# #新来一个元素，查看这个元素是否在集合中，如果在则查看这个元素在字典中的index，index/count_not_zero(sorted_word2tfidf)
# def get_weight(sorted_word2tfidf,set,words):
#     score = 0.0
#     words = filter(words.split()).split()
#     for word in words:
#         if word in set:
#             #获取key为word的index
#             index = 0
#             for i in range(len(sorted_word2tfidf)):
#                 if sorted_word2tfidf[i][0] == word:
#                     index = i
#                     break
#             # score += 100 * (count_not_zero(sorted_word2tfidf) / 3 - index) * sorted_word2tfidf[index][1]/(count_not_zero(sorted_word2tfidf) / 3)
#             # score += 100 * sorted_word2tfidf[index][1]
#             score += 1/(index+0.1) 
#         else:
#             score += 0
#     return score
    
import csv
import math
import time

from tqdm import tqdm
#用自身测试一下




# path6_v_i_t = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/AttType6_headTo_v_i_t.csv"
# f6_v = open(path6_v_i_t, 'r')
# lines6 = csv.reader(f6_v)

# ii = 0
# for line in lines6:
#     print(line)
#     v6 = line[1]
#     i6 = line[2]
#     t6 = line[3]
#     #print(v6,i6,t6)
#     score_0 = 7 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
#     score_1 = 1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
#     score_2 = 0.3 * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
#     score_3 = 0.08 * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
#     score_4 = 0.04 * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
#     score_5 = 0.1 * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)
#     #输出最大的那个的index
#     list_temp = [score_0,score_1, score_2, score_3, score_4, score_5]
#     print(list_temp.index(max(list_temp)))
#     # print(score_0,score_1,score_2,score_3,score_4,score_5)
#     ii += 1
#     if ii == 10:
#         break
#     # v6 = filter(v6.split())



import numpy as np

# list_0 = [30185, 54381, 22348, 73408, 6060, 56685, 54584, 18600, 20211, 40647, 41183, 74778, 65506, 54372, 70666, 52842, 39757, 69397, 20409, 36700, 78402, 9857, 59140, 14152, 68414, 62456, 17887, 26046, 44000, 40829, 66620, 53738, 43327, 69629, 2292, 40831, 32127, 59079, 76654, 60879, 7886, 35037, 56437, 71663, 42746, 54114, 73271, 8571, 21803, 24824, 52491, 54135, 31808, 57702, 11583, 22230, 63783, 1603, 70816, 54207, 22911, 13872, 57626, 43208, 50594, 13740, 40045, 48923, 63613, 61673, 75718, 70784, 13385, 64043, 9631, 62143, 41431, 69712, 5606, 15382, 19979, 74887, 38844, 28205, 33152, 28835, 28218, 41018, 24471, 39325, 57204, 10289, 31418, 27744, 71569, 33049, 14072, 53713, 43411, 31834]
# list_1 = [3415, 8755, 2475, 3922, 4897, 7432, 5078, 921, 5301, 95, 3264, 4064, 1554, 818, 7766, 5882, 9075, 52, 9882, 3512, 5274, 1338, 2380, 1162, 5596, 1287, 56, 9211, 3779, 2044, 4885, 2073, 378, 2271, 735, 2054, 8095, 830, 8933, 3765, 4151, 809, 9121, 1653, 7768, 5092, 9475, 8204, 1460, 2863, 6050, 1666, 8071, 5502, 6593, 8888, 3225, 5705, 298, 6582, 2462, 4033, 98, 1081, 8434, 10630, 2283, 4578, 8191, 8906, 5224, 7548, 7489, 1520, 8019, 3579, 5860, 2009, 7114, 5643, 4060, 9480, 7197, 1532, 151, 9680, 7160, 3448, 6813, 1295, 2890, 10443, 587, 1848, 8722, 6764, 10029, 564, 7797, 6250]

#p1从0.1到3.5,步长0.1
pf = [0.001,0.0001,0.00001,0.000001,0.0000001,0.00000001,0.000000001,0.0000000001,0.00000000001]
p0 = [1]
p1 = [1]

    
path0 = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/AttType0_headTo_v_i_t.csv"
path1 = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/AttType1_headTo_v_i_t.csv"
#各自生成文件长度中的100个随机数
import random
import numpy as np
import csv
import multiprocessing

def random_num(path,length):
    f = open(path, 'r')
    
    lines = list(csv.reader(f))
    # print(length)
    #生成100个随机数
    list_ = []
    while len(list_) < 5000:
        random_num = random.randint(0, length)
        
        #检查这行的元素
        if lines[random_num][1] == '' and lines[random_num][2] == '' and lines[random_num][3] == '':
            continue
        else:
            list_.append(random_num)
        # print(lines[random_num])
        # print(random_num)
    return list_

# list_0 = random_num(path0, 78466)
# list_1 = random_num(path1,10691)
# print("拿到数据index")   

path6_v_i_t_0 = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/AttType0_headTo_v_i_t.csv"
f6_v_0 = open(path6_v_i_t_0, 'r')
lines6_0 = list(csv.reader(f6_v_0))

path6_v_i_t_1 = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/AttType1_headTo_v_i_t.csv"
f6_v_1 = open(path6_v_i_t_1, 'r')
lines6_1 = list(csv.reader(f6_v_1))

def runsome(start):
    time1 = time.time()
    print(f"进程中开始{start}\n")
    #定义函数
    def get_weight(sorted_word2tfidf,set,words):
        score = 0.0
        words = filter(words.split()).split()
        for word in words:
            if word in set:
                #获取key为word的index
                index = 0
                for i in range(len(sorted_word2tfidf)):
                    if sorted_word2tfidf[i][0] == word:
                        index = i
                        break
                # score += 100 * (count_not_zero(sorted_word2tfidf) / 3 - index) * sorted_word2tfidf[index][1]/(count_not_zero(sorted_word2tfidf) / 3)
                # score += 100 * sorted_word2tfidf[index][1]
                # score += 1 / math.exp(index / (count_not_zero(sorted_word2tfidf)) + start) 
                # score += math.pi/2 - math.atan(start*index) 
                score += sorted_word2tfidf[index][1]
            else:
                score += 0
        return score
    
    
    para0 = 0
    para1 = 0
    sum = 0
    sum0 = 0
    sum1 = 0
    sum = 0

    list_0 = random_num(path0, 78466)
    list_1 = random_num(path1,10691)

    for pi0 in p0 :
        for pi1 in p1:
            
            ii = 0
            jj = 0
            wrong = 0
            for i in list_0:
                line = lines6_0[i]
                # print(line)
                v6 = line[1]
                i6 = line[2]
                t6 = line[3]
                # #print(v6,i6,t6)
                score_0 = pi0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
                score_1 = pi1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
                
                list_temp = [score_0,score_1]#, score_2, score_3, score_4, score_5]
                #class_ = list_temp.index(max(list_temp))
            
                ii += 1
                

                if class_ == 0:
                    jj += 1
                # else:
                #     wrong += 1
                #     if wrong > 300 - sum0 + 100:
                #         break

                # if ii == 100:
                #     break
            
            temp = jj
            wrong = 0
            
            ii = 0
            kk = 0
            for i in list_1:
                line = lines6_1[i]
                
                # print(line)
                v6 = line[1]
                i6 = line[2]
                t6 = line[3]
                # #print(v6,i6,t6)
                score_0 = pi0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
                score_1 = pi1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
                
                list_temp = [score_0,score_1]#, score_2, score_3, score_4, score_5]
                class_ = list_temp.index(max(list_temp))
                
                ii += 1
                

                if class_ == 1:
                    kk += 1
                # else:
                #     wrong += 1
                #     if wrong > 300 - sum1 + 100:
                #         break
                # if ii == 100:
                #     break
            temp += kk
            if temp > sum:
                sum = temp
                para0 = pi0
                para1 = pi1
                sum0 = jj
                sum1 = kk
            # break
        # break
    print(f"进程:{start} 耗时：{time.time()- time1} p0: {para0} p1: {para1} sum:{sum} sum0: {sum0} sum1: {sum1} \n")


def sum8(start):
    print(f"进程中开始{start}\n")

    print("进程中结束\n")

pool = multiprocessing.Pool(processes=9)
for i in range(9):
    start = pf[i]
    
    # end = (i + 2) * 0.01
    #运行run函数

    pool.apply_async(runsome, (start,))

pool.close()
pool.join()



# print(sum)
# print(para0,para1)
# print(sum0,sum1)
# print(pf_)
# Out:
# 进程中开始1e-11
# 进程中开始1e-10
# 进程中开始1e-09
#
#
#
# 进程中开始1e-05
# 进程中开始0.0001
# 进程中开始1e-07
# 进程中开始1e-08
# 进程中开始1e-06
#
# 进程中开始0.001
#
#
#
#
#
# 进程:1e-05 耗时：51.52330207824707 p0: 1 p1: 1 sum:7742 sum0: 3364 sum1: 4378
#
# 进程:0.001 耗时：51.97596597671509 p0: 1 p1: 1 sum:7771 sum0: 3341 sum1: 4430
#
# 进程:1e-09 耗时：52.22059512138367 p0: 1 p1: 1 sum:7693 sum0: 3277 sum1: 4416
#
# 进程:1e-06 耗时：52.339985609054565 p0: 1 p1: 1 sum:7691 sum0: 3341 sum1: 4350
#
# 进程:1e-08 耗时：52.941082239151 p0: 1 p1: 1 sum:7775 sum0: 3363 sum1: 4412
#
# 进程:1e-10 耗时：52.94814085960388 p0: 1 p1: 1 sum:7698 sum0: 3334 sum1: 4364
#
# 进程:0.0001 耗时：53.20611214637756 p0: 1 p1: 1 sum:7749 sum0: 3359 sum1: 4390

# %%
#专门处理other类

    
import csv
import math
#用自身测试一下



path6_v_i_t = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/AttType6_headTo_v_i_t.csv"
f6_v = open(path6_v_i_t, 'r')
lines6 = csv.reader(f6_v)

import numpy as np

ii = 0
jj = 0
for line in lines6:
    # print(line)
    v6 = line[1]
    i6 = line[2]
    t6 = line[3]
    # #print(v6,i6,t6)
    score_0 = math.log(1+7) * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    score_1 = math.log(1+1) * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    # score_2 = math.log(1+0.3) * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    # score_3 = math.log(1+0.08) * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    # score_4 = math.log(1+0.04) * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    # score_5 = math.log(1+0.1) * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)

    # score_0 = para0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    # score_1 = para1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    # score_2 = para2 * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    # score_3 = para3 * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    # score_4 = para4 * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    # score_5 = para5 * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)

    list_temp = [score_0,score_1]#, score_2, score_3, score_4, score_5]
    class_ = list_temp.index(max(list_temp))
    # print(class_)

    # score_0 = np.arctan(10*7) * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    # score_1 = np.arctan(10*1) * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    # score_2 = np.arctan(10*0.3) * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    # score_3 = np.arctan(10*0.08) * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    # score_4 = np.arctan(10*0.04) * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    # score_5 = np.arctan(10*0.1) * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)

    # score_0 = (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    # score_1 = (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    # score_2 = (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    # score_3 = (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    # score_4 = (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    # score_5 = (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)
    #输出最大的那个的index
    
    # print(list_temp.index(max(list_temp)))

    
    # # print(score_0,score_1,score_2,score_3,score_4,score_5)
    ii += 1
    # if ii == 80:
    #     break

    if class_ == 1:
        jj += 1

print(jj)
print(ii)

# %%
#专门处理other类

#新来一个元素，查看这个元素是否在集合中，如果在则查看这个元素在字典中的index，index/count_not_zero(sorted_word2tfidf)
def get_weight(sorted_word2tfidf,set,words):
    score = 0.0
    words = filter(words.split()).split()
    for word in words:
        if word in set:
            #获取key为word的index
            index = 0
            for i in range(len(sorted_word2tfidf)):
                if sorted_word2tfidf[i][0] == word:
                    index = i
                    break
            # score += 100 * (count_not_zero(sorted_word2tfidf) / 3 - index) * sorted_word2tfidf[index][1]/(count_not_zero(sorted_word2tfidf) / 3)
            score += 100 * sorted_word2tfidf[index][1]
        else:
            score += 0
    return score
    
import csv
import math
#用自身测试一下



path6_v_i_t = "/home/user/Programs/PMA_lihang/mypaper/data/1_3_aspects/AttType2_headTo_v_i_t.csv"
f6_v = open(path6_v_i_t, 'r')
lines6 = csv.reader(f6_v)

import numpy as np

max_right = 0
para0 = 0.1
para1 = 0.1
para2 = 0.1
para3 = 0.1
para4 = 0.1
para5 = 0.1

all_items = 78442+10690+3043+839+416+1166
ii = 0


for line in lines6:

    v6 = line[1]
    i6 = line[2]
    t6 = line[3]
    

    score_0 = para0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3) 
    score_1 = para1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
    score_2 = para2 * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
    score_3 = para3 * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
    score_4 = para4 * (get_weight(sorted_word2tfidf4_v,set_v4,v6) * 5 + get_weight(sorted_word2tfidf4_i,set_i4,i6) * 4 + get_weight(sorted_word2tfidf4_t,set_t4,t6) * 3)
    score_5 = para5 * (get_weight(sorted_word2tfidf5_v,set_v5,v6) * 5 + get_weight(sorted_word2tfidf5_i,set_i5,i6) * 4 + get_weight(sorted_word2tfidf5_t,set_t5,t6) * 3)

    list_temp = [score_0,score_1, score_2, score_3, score_4, score_5]
    class_ = list_temp.index(max(list_temp))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_526815/3298108585.py in <module>
#      51
#      52     score_0 = para0 * (get_weight(sorted_word2tfidf0_v,set_v0,v6) * 5 + get_weight(sorted_word2tfidf0_i,set_i0,i6) * 4 + get_weight(sorted_word2tfidf0_t,set_t0,t6) * 3)
# ---> 53     score_1 = para1 * (get_weight(sorted_word2tfidf1_v,set_v1,v6) * 5 + get_weight(sorted_word2tfidf1_i,set_i1,i6) * 4 + get_weight(sorted_word2tfidf1_t,set_t1,t6) * 3)
#      54     score_2 = para2 * (get_weight(sorted_word2tfidf2_v,set_v2,v6) * 5 + get_weight(sorted_word2tfidf2_i,set_i2,i6) * 4 + get_weight(sorted_word2tfidf2_t,set_t2,t6) * 3)
#      55     score_3 = para3 * (get_weight(sorted_word2tfidf3_v,set_v3,v6) * 5 + get_weight(sorted_word2tfidf3_i,set_i3,i6) * 4 + get_weight(sorted_word2tfidf3_t,set_t3,t6) * 3)
#
# /tmp/ipykernel_526815/3298108585.py in get_weight(sorted_word2tfidf, set, words)
#      10             index = 0
#      11             for i in range(len(sorted_word2tfidf)):
# ---> 12                 if sorted_word2tfidf[i][0] == word:
#      13                     index = i
#      14                     break
#
# KeyboardInterrupt:
